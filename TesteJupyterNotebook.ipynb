# %% [markdown]
# ## sub7

# %%
a = 1
print(a)
# Out:
# 1

# %% [markdown]
# ## sub 6

# %%
print('hello world')
# Out:
# hello world

# %%
list_files = ['file1.txt', 'file2.tif', 'file3.asc', 'image.tif', 'document.pdf', 'map.tif', 'notes.docx']
#files_tif = [f for f in list_files if f.endswith('.tif')]

for f in list_files:
    if f[-4::] == '.tif':
        print(f)
# Out:
# file2.tif
# image.tif
# map.tif

# %%
a = 'fghjklç.tif'

print(a[-4::])
# Out:
# .tif
